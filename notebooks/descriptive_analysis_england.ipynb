# %% [markdown]
# <a href="https://colab.research.google.com/github/dbckz/crossing-the-line/blob/master/notebooks/descriptive_analysis_england.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import ast
import os
import matplotlib.pyplot as plt
import statsmodels.api as sm
from wordcloud import WordCloud
import dateutil
from tqdm import tqdm
from google.colab import drive
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from sklearn.linear_model import LinearRegression
from statsmodels.genmod.generalized_estimating_equations import GEE
from statsmodels.genmod.cov_struct import (Exchangeable,
    Independence,Autoregressive)
from statsmodels.genmod.families import Poisson

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root_path = "/content/drive/MyDrive/University/Dissertation"
regression_path = "/regression"

pens_df = pd.read_csv(root_path + regression_path + "/pens.csv",
                     parse_dates=['date'])

# %%
pens_df['hatebase_proportion'] = pens_df['tweets_containing_slurs'] / pens_df['total_tweets']
pens_df['perspective_proportion'] = pens_df['tweets_flagged_perspective'] / pens_df['total_perspective_tweets']

# Set to 0 where there's 0 tweets received
pens_df['hatebase_proportion'].fillna(0.0, inplace=True)
pens_df['perspective_proportion'].fillna(0.0, inplace=True)
pens_df['player_rating'].fillna(0.0, inplace=True)
pens_df['player_rating_in_previous_game'].fillna(0.0, inplace=True)
pens_df['club_coefficient'].fillna(0.0, inplace=True)

# %%
pens_df = pens_df[pens_df['days_since_defeat'] <= 2][pens_df['featured'] == True]
# Out:
# <ipython-input-5-f87ff57f7bba>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pens_df = pens_df[pens_df['days_since_defeat'] <= 2][pens_df['featured'] == True]

# %%
agged = pens_df.groupby(['name']).agg('sum')

agged['hatebase_proportion'] = agged['tweets_containing_slurs'] / agged['total_tweets']
agged['perspective_proportion'] = agged['tweets_flagged_perspective'] / agged['total_perspective_tweets']

agged.drop(['Antoine Griezmann', 'Benjamin Pavard', 'Clément Lenglet', 'Karim Benzema', 'Kylian Mbappé', 'Marcus Thuram', 'Moussa Sissoko', "N'Golo Kanté", 'Olivier Giroud', 'Paul Pogba', 'Presnel Kimpembe', 'Raphaël Varane'], inplace=True)

# %%
agged['color'] = np.where((agged.pen == -1),'red',agged.pen)
agged['color'] = np.where((agged.pen == 0),'orange',agged.color)
agged['color'] = np.where((agged.pen == 1),'green',agged.color)

# %%
agged
# Out:
#                   country_ranking_points  club_coefficient  days_since_defeat  \
# name
# Bukayo Saka                         1687              99.0                  0
# Declan Rice                         1687               1.5                  0
# Harry Kane                          1687              88.0                  0
# Harry Maguire                       1687             113.0                  0
# Jack Grealish                       1687               0.0                  0
# Jadon Sancho                        1687              90.0                  0
# Jordan Henderson                    1687             101.0                  0
# Jordan Pickford                     1687               3.0                  0
# Kalvin Phillips                     1687               0.0                  0
# Kieran Trippier                     1687             115.0                  0
# Kyle Walker                         1687             125.0                  0
# Luke Shaw                           1687             113.0                  0
# Marcus Rashford                     1687             113.0                  0
# Mason Mount                         1687              98.0                  0
# Raheem Sterling                     1687             125.0                  0
#
#                   featured  player_rating  matchday  \
# name
# Bukayo Saka              1           5.79         1
# Declan Rice              1           7.50         1
# Harry Kane               1           7.20         1
# Harry Maguire            1           7.11         1
# Jack Grealish            1           6.46         1
# Jadon Sancho             1           5.66         1
# Jordan Henderson         1           6.21         1
# Jordan Pickford          1           7.73         1
# Kalvin Phillips          1           6.46         1
# Kieran Trippier          1           7.04         1
# Kyle Walker              1           6.04         1
# Luke Shaw                1           7.10         1
# Marcus Rashford          1           5.40         1
# Mason Mount              1           6.12         1
# Raheem Sterling          1           6.62         1
#
#                   featured_in_previous_game  player_rating_in_previous_game  \
# name
# Bukayo Saka                               1                            6.18
# Declan Rice                               1                            6.36
# Harry Kane                                1                            7.46
# Harry Maguire                             1                            8.13
# Jack Grealish                             1                            6.38
# Jadon Sancho                              0                            0.00
# Jordan Henderson                          1                            6.28
# Jordan Pickford                           1                            5.84
# Kalvin Phillips                           1                            6.75
# Kieran Trippier                           1                            5.96
# Kyle Walker                               1                            7.13
# Luke Shaw                                 1                            7.18
# Marcus Rashford                           0                            0.00
# Mason Mount                               1                            7.22
# Raheem Sterling                           1                            8.17
#
#                   pen_in_previous_game  red_card  penalty  penalty_outcome  \
# name
# Bukayo Saka                          0         0        1                0
# Declan Rice                          0         0        0                0
# Harry Kane                          -1         0        1                1
# Harry Maguire                        0         0        1                1
# Jack Grealish                        0         0        0                0
# Jadon Sancho                         0         0        1                0
# Jordan Henderson                     0         0        0                0
# Jordan Pickford                      0         0        0                0
# Kalvin Phillips                      0         0        0                0
# Kieran Trippier                      0         0        0                0
# Kyle Walker                          0         0        0                0
# Luke Shaw                            0         0        0                0
# Marcus Rashford                      0         0        1                0
# Mason Mount                          0         0        0                0
# Raheem Sterling                      0         0        0                0
#
#                   pen  total_tweets  total_perspective_tweets  \
# name
# Bukayo Saka        -1         44790                     44790
# Declan Rice         0          2666                      2666
# Harry Kane          1          7206                      7206
# Harry Maguire       1          4604                      4604
# Jack Grealish       0          4525                      4525
# Jadon Sancho       -1         15909                     15909
# Jordan Henderson    0          1864                      1864
# Jordan Pickford     0          3636                      3636
# Kalvin Phillips     0          2505                      2505
# Kieran Trippier     0           514                       514
# Kyle Walker         0           635                       635
# Luke Shaw           0          7367                      7367
# Marcus Rashford    -1         38647                     38647
# Mason Mount         0          1767                      1767
# Raheem Sterling     0          7307                      7307
#
#                   tweets_containing_slurs  tweets_flagged_perspective  \
# name
# Bukayo Saka                           238                         202
# Declan Rice                             8                          12
# Harry Kane                             33                          38
# Harry Maguire                          23                          20
# Jack Grealish                          24                          16
# Jadon Sancho                          111                          99
# Jordan Henderson                       14                           9
# Jordan Pickford                        11                          17
# Kalvin Phillips                         2                           6
# Kieran Trippier                         1                           0
# Kyle Walker                             6                           2
# Luke Shaw                              21                          25
# Marcus Rashford                       249                         667
# Mason Mount                             4                           2
# Raheem Sterling                        40                          52
#
#                   hatebase_proportion  perspective_proportion   color
# name
# Bukayo Saka                  0.005314                0.004510     red
# Declan Rice                  0.003001                0.004501  orange
# Harry Kane                   0.004580                0.005273   green
# Harry Maguire                0.004996                0.004344   green
# Jack Grealish                0.005304                0.003536  orange
# Jadon Sancho                 0.006977                0.006223     red
# Jordan Henderson             0.007511                0.004828  orange
# Jordan Pickford              0.003025                0.004675  orange
# Kalvin Phillips              0.000798                0.002395  orange
# Kieran Trippier              0.001946                0.000000  orange
# Kyle Walker                  0.009449                0.003150  orange
# Luke Shaw                    0.002851                0.003394  orange
# Marcus Rashford              0.006443                0.017259     red
# Mason Mount                  0.002264                0.001132  orange
# Raheem Sterling              0.005474                0.007116  orange

# %%
data = go.Bar(
    x = agged[['pen','tweets_flagged_perspective']][agged['tweets_flagged_perspective'] > 0].sort_values('tweets_flagged_perspective', ascending=False).index,
    y = agged[['pen','tweets_flagged_perspective']][agged['tweets_flagged_perspective'] > 0].sort_values('tweets_flagged_perspective', ascending=False).tweets_flagged_perspective,
    marker_color=agged[['pen','tweets_flagged_perspective', 'color']][agged['tweets_flagged_perspective'] > 0].sort_values('tweets_flagged_perspective', ascending=False).color
)

layout = go.Layout(yaxis_title="Number of tweets flagged by Perspective")

figure = go.Figure(data = data, layout = layout)
figure.write_html("/content/drive/MyDrive/University/Dissertation/images/figure4d.html", include_plotlyjs='cdn')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5a46b40a-ab1b-46d6-bbe6-e3fd415fc005" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a46b40a-ab1b-46d6-bbe6-e3fd415fc005")) {                    Plotly.newPlot(                        "5a46b40a-ab1b-46d6-bbe6-e3fd415fc005",                        [{"marker":{"color":["red","red","red","orange","green","orange","green","orange","orange","orange","orange","orange","orange","orange"]},"x":["Marcus Rashford","Bukayo Saka","Jadon Sancho","Raheem Sterling","Harry Kane","Luke Shaw","Harry Maguire","Jordan Pickford","Jack Grealish","Declan Rice","Jordan Henderson","Kalvin Phillips","Kyle Walker","Mason Mount"],"y":[667,202,99,52,38,25,20,17,16,12,9,6,2,2],"type":"bar"}],                        {"yaxis":{"title":{"text":"Number of tweets flagged by Perspective"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"au ...

# %% [markdown]
# # Pens

# %%
for x in range(2):
  print(pens_df[['name', 'pen','tweets_flagged_perspective']][pens_df['days_since_defeat'] == x].sort_values('tweets_flagged_perspective', ascending=False))
# Out:
#                   name  pen  tweets_flagged_perspective
# 9      Marcus Rashford   -1                         667
# 22         Bukayo Saka   -1                         202
# 14        Jadon Sancho   -1                          99
# 151      Kylian Mbappé   -1                          59
# 8      Raheem Sterling    0                          52
# 7           Harry Kane    1                          38
# 2            Luke Shaw    0                          25
# 148         Paul Pogba    1                          22
# 4        Harry Maguire    1                          20
# 0      Jordan Pickford    0                          17
# 5        Jack Grealish    0                          16
# 158      Karim Benzema    0                          16
# 3          Declan Rice    0                          12
# 6     Jordan Henderson    0                           9
# 12     Kalvin Phillips    0                           6
# 147    Clément Lenglet    0                           2
# 16         Mason Mount    0                           2
# 1          Kyle Walker    0                           2
# 153       N'Golo Kanté    0                           1
# 146     Raphaël Varane    0                           0
# 145   Presnel Kimpembe    1                           0
# 144    Benjamin Pavard    0                           0
# 149  Antoine Griezmann    0                           0
# 150     Olivier Giroud    1                           0
# 156     Moussa Sissoko    0                           0
# 10     Kieran Trippier    0                           0
# 164      Marcus Thuram    1                           0
# Empty DataFrame
# Columns: [name, pen, tweets_flagged_perspective]
# Index: []

# %%
fig = px.line(pens_df, x="days_since_defeat", y="tweets_flagged_perspective", color='name')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f47cc930-80f8-4187-b8b3-2d3c729d2375" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f47cc930-80f8-4187-b8b3-2d3c729d2375")) {                    Plotly.newPlot(                        "f47cc930-80f8-4187-b8b3-2d3c729d2375",                        [{"hovertemplate":"name=Jordan Pickford<br>days_since_defeat=%{x}<br>tweets_flagged_perspective=%{y}<extra></extra>","legendgroup":"Jordan Pickford","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Jordan Pickford","orientation":"v","showlegend":true,"x":[0],"xaxis":"x","y":[17],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Kyle Walker<br>days_since_defeat=%{x}<br>tweets_flagged_perspective=%{y}<extra></extra>","legendgroup":"Kyle Walker","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Kyle Walker","orientation":"v","showlegend":true,"x":[0],"xaxis":"x","y":[2],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Luke Shaw<br>days_since_defeat=%{x}<br>tweets_flagged_perspective=%{y}<extra></extra>","legendgroup":"Luke Shaw","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Luke Shaw","orientation":"v","showlegend":true,"x":[0],"xaxis":"x","y":[25],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Declan Rice<br>days_since_defeat=%{x}<br>tweets_flagged_perspective=%{y}<extra></extra>","legendgroup":"Declan Rice","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Declan Rice","orientation":"v","showlegend":true,"x":[0],"xaxis":"x","y":[12],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Harry Maguire<br>days_since_defeat=%{x}<br>tweets_flagged_perspective=%{y}<extra></extra>","legendgroup":"Harry Maguire","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Harry Maguire","orientation":"v","showlegend":true,"x":[0],"xaxis":"x","y":[20],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Jack Grealish<br>days_since_defeat=%{x}<br>tweets_flagged_perspective=%{y}<extra></extra>","legendgroup":"Jack Grealish","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Jack Grealish","orientation":"v","showlegend":true,"x":[0],"xaxis":"x","y":[16],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Jordan Henderson<br>days_since_defeat=%{x}<br>tweets_flagged_perspective=%{y}<extra></extra>","legendgroup":"Jordan Henderson","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Jordan Henderson","orientation":"v","showlegend":true,"x":[0],"xaxis":"x","y":[9],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Harry Kane<br>days_since_defeat=%{x}<br>tweets_flagged_perspective=%{y}<extra></extra>","legendgroup":"Harry Kane","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Harry Kane","orientation":"v","showlegend":true,"x":[0],"xaxis":"x","y":[38],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Raheem Sterling<br>days_since_defeat=%{x}<br>tweets_flagged_perspective=%{y}<extra></extra>","legendgroup":"Raheem Sterling","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Raheem Sterling","orientation":"v","showlegend":true,"x":[0],"xaxis":"x","y":[52],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Marcus Rashford<br>days_since_defeat=%{x}<br>tweets_flagged_perspective=%{y}<extra></extra>","legendgroup":"Marcus Rashford","line":{"color":"#FECB52","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Marcus Rashford","orientation":"v","showlegend":true,"x":[0],"xaxis":"x","y":[667],"yaxis":"y ...

# %% [markdown]
# # Race

# %%
reg_df = pd.read_csv(root_path + regression_path + "/regression_table_with_persp.csv",
                     parse_dates=['date'])

reg_df['hatebase_proportion'] = reg_df['tweets_containing_slurs'] / reg_df['total_tweets']
reg_df['perspective_proportion'] = reg_df['tweets_flagged_perspective'] / reg_df['total_perspective_tweets']

# Set to 0 where there's 0 tweets received
reg_df['hatebase_proportion'].fillna(0.0, inplace=True)
reg_df['perspective_proportion'].fillna(0.0, inplace=True)
reg_df['player_rating'].fillna(0.0, inplace=True)
reg_df['player_rating_in_previous_game'].fillna(0.0, inplace=True)
reg_df['club_coefficient'].fillna(0.0, inplace=True)

# %%
reg_df = reg_df[(reg_df['days_since_last_game'] == 0) | (reg_df['days_since_last_game'] == 1) | (reg_df['days_since_last_game'] == 2)]
reg_df[reg_df['name'] == 'Thibaut Courtois']
# Out:
#                   name  country  country_ranking_points               club  \
# 118   Thibaut Courtois  Belgium                    1783  Spain Real Madrid
# 236   Thibaut Courtois  Belgium                    1783  Spain Real Madrid
# 354   Thibaut Courtois  Belgium                    1783  Spain Real Madrid
# 826   Thibaut Courtois  Belgium                    1783  Spain Real Madrid
# 944   Thibaut Courtois  Belgium                    1783  Spain Real Madrid
# 1062  Thibaut Courtois  Belgium                    1783  Spain Real Madrid
# 1416  Thibaut Courtois  Belgium                    1783  Spain Real Madrid
# 1534  Thibaut Courtois  Belgium                    1783  Spain Real Madrid
# 1652  Thibaut Courtois  Belgium                    1783  Spain Real Madrid
#
#       club_coefficient           handle ethnicity       date  \
# 118              127.0  thibautcourtois     white 2021-06-21
# 236              127.0  thibautcourtois     white 2021-06-22
# 354              127.0  thibautcourtois     white 2021-06-23
# 826              127.0  thibautcourtois     white 2021-06-27
# 944              127.0  thibautcourtois     white 2021-06-28
# 1062             127.0  thibautcourtois     white 2021-06-29
# 1416             127.0  thibautcourtois     white 2021-07-02
# 1534             127.0  thibautcourtois     white 2021-07-03
# 1652             127.0  thibautcourtois     white 2021-07-04
#
#       days_since_last_game  featured  ... red_card  penalty  penalty_outcome  \
# 118                    0.0      True  ...    False    False            False
# 236                    1.0     False  ...    False    False            False
# 354                    2.0     False  ...    False    False            False
# 826                    0.0      True  ...    False    False            False
# 944                    1.0     False  ...    False    False            False
# 1062                   2.0     False  ...    False    False            False
# 1416                   0.0      True  ...    False    False            False
# 1534                   1.0     False  ...    False    False            False
# 1652                   2.0     False  ...    False    False            False
#
#      pen  total_tweets  total_perspective_tweets tweets_containing_slurs  \
# 118    0           238                       238                       0
# 236    0            23                        23                       0
# 354    0           116                       116                       0
# 826    0           579                       579                       1
# 944    0           208                       208                       0
# 1062   0            61                        61                       0
# 1416   0           339                       339                       0
# 1534   0           120                       120                       1
# 1652   0            38                        38                       0
#
#       tweets_flagged_perspective hatebase_proportion  perspective_proportion
# 118                            0            0.000000                0.000000
# 236                            0            0.000000                0.000000
# 354                            0            0.000000                0.000000
# 826                            0            0.001727                0.000000
# 944                            1            0.000000                0.004808
# 1062                           1            0.000000                0.016393
# 1416                           0            0.000000                0.000000
# 1534                           0            0.008333                0.000000
# 1652                           1            0.000000                0.026316
#
# [9 rows x 29 columns]

# %%
sco = reg_df[reg_df['country'] == 'Scotland'].index
fra = reg_df[reg_df['country'] == 'France'].index
ger = reg_df[reg_df['country'] == 'Germany'].index
ned = reg_df[reg_df['country'] == 'Netherlands'].index
bel = reg_df[reg_df['country'] == 'Belgium'].index
reg_df.drop(sco, inplace = True)
reg_df.drop(fra, inplace = True)
reg_df.drop(ger, inplace = True)
reg_df.drop(ned, inplace = True)
reg_df.drop(bel, inplace = True)


# saka = reg_df[reg_df['name'] == 'Bukayo Saka'].index
# rashford = reg_df[reg_df['name'] == 'Marcus Rashford'].index
# sancho = reg_df[reg_df['name'] == 'Jadon Sancho'].index
# reg_df.drop(saka, inplace = True)
# reg_df.drop(rashford, inplace = True)
# reg_df.drop(sancho, inplace = True)

# %%
reg_df['result'] = reg_df['result'].fillna('A')

# %%
reg_df = reg_df.groupby(['name', 'opponent']).agg(({
    'total_tweets': sum,
    'tweets_containing_slurs': sum,
    'tweets_flagged_perspective': sum,
    'hatebase_proportion': 'mean',
    'perspective_proportion': 'mean',
    'ethnicity': max,
    'result': max
    }
    ))

reg_df['hatebase_proportion'] = reg_df['tweets_containing_slurs'] / reg_df['total_tweets']
reg_df['perspective_proportion'] = reg_df['tweets_flagged_perspective'] / reg_df['total_tweets']

# %%
tmp_L = reg_df[reg_df['result'] == 'L']
print(tmp_L['tweets_containing_slurs'].mean())
print(tmp_L['tweets_flagged_perspective'].mean())
print(tmp_L['hatebase_proportion'].mean() * 100)
print(tmp_L['perspective_proportion'].mean()* 100) 

ethnicity_df_L = tmp_L.groupby('ethnicity').agg(({
    'tweets_containing_slurs': 'mean',
    'tweets_flagged_perspective': 'mean',
    'hatebase_proportion': 'mean',
    'perspective_proportion': 'mean'
    }
    ))
# Out:
# 98.25
# 86.83333333333333
# 0.3237935653209099
# 0.24622241478249543

# %%
ethnicity_df_L['ethnicity_text'] = np.where((ethnicity_df_L.index == 'white'),'White',ethnicity_df_L.index)
ethnicity_df_L['ethnicity_text'] = np.where((ethnicity_df_L.index == 'non_white'),'Other than White',ethnicity_df_L.ethnicity_text)

ethnicity_df_L
# Out:
#            tweets_containing_slurs  tweets_flagged_perspective  \
# ethnicity
# non_white               217.111111                  199.222222
# white                    26.933333                   19.400000
#
#            hatebase_proportion  perspective_proportion    ethnicity_text
# ethnicity
# non_white             0.004197                0.003307  Other than White
# white                 0.002663                0.001955             White

# %%
normalising_factor = 100 / ethnicity_df_L['perspective_proportion'].max()

data = go.Bar(
    y = ethnicity_df_L.ethnicity_text,
    x = ethnicity_df_L.perspective_proportion * 100,
    text = ethnicity_df_L.perspective_proportion * 100,
    textposition = 'outside',
    texttemplate = '%{text:.5f}',
    orientation='h',
    width=[0.5]*2
)

layout = go.Layout(xaxis = dict(
        showticklabels = False,
        title = "Proportion of tweets flagged by Perspective"
    ))



figure = go.Figure(data = data, layout = layout)

figure.update_traces(marker_color='green')
figure.show()

# This basically shows that on matchdays where they lose, non white players get twice as much abuse as white players
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9d7602db-0cd0-4a04-8852-f3729124471c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d7602db-0cd0-4a04-8852-f3729124471c")) {                    Plotly.newPlot(                        "9d7602db-0cd0-4a04-8852-f3729124471c",                        [{"orientation":"h","text":[0.3307478842925963,0.19550713307643486],"textposition":"outside","texttemplate":"%{text:.5f}","width":[0.5,0.5],"x":[0.3307478842925963,0.19550713307643486],"y":["Other than White","White"],"type":"bar","marker":{"color":"green"}}],                        {"xaxis":{"showticklabels":false,"title":{"text":"Proportion of tweets flagged by Perspective"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"c ...

# %%
data = go.Bar(
    y = ethnicity_df_L.ethnicity_text,
    x = ethnicity_df_L.tweets_flagged_perspective,
    text = ethnicity_df_L.tweets_flagged_perspective,
    textposition = 'outside',
    texttemplate = '%{text:.1f}',
    orientation='h',
    width=[0.5]*2
)

layout = go.Layout(xaxis = dict(
                showticklabels = False,
                title = "Number of tweets flagged by Perspective (per player)"

    ))

figure = go.Figure(data = data, layout = layout)
figure.update_traces(marker_color='green')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d33e3a1c-1581-434c-863a-c5bee98bf2ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d33e3a1c-1581-434c-863a-c5bee98bf2ac")) {                    Plotly.newPlot(                        "d33e3a1c-1581-434c-863a-c5bee98bf2ac",                        [{"orientation":"h","text":[199.22222222222223,19.4],"textposition":"outside","texttemplate":"%{text:.1f}","width":[0.5,0.5],"x":[199.22222222222223,19.4],"y":["Other than White","White"],"type":"bar","marker":{"color":"green"}}],                        {"xaxis":{"showticklabels":false,"title":{"text":"Number of tweets flagged by Perspective (per player)"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewid ...

# %%
tmp_W = reg_df[reg_df['result'] == 'W']
print(tmp_W['tweets_containing_slurs'].mean())
print(tmp_W['tweets_flagged_perspective'].mean())
print(tmp_W['hatebase_proportion'].mean() * 100)
print(tmp_W['perspective_proportion'].mean()* 100) 

ethnicity_df_W = tmp_W.groupby('ethnicity').agg(({
    'tweets_containing_slurs': 'mean',
    'tweets_flagged_perspective': 'mean',
    'hatebase_proportion': 'mean',
    'perspective_proportion': 'mean'
    }
    ))
# Out:
# 11.645833333333334
# 10.34375
# 0.28336080886638265
# 0.15698201324446812

# %%
ethnicity_df_W['ethnicity_text'] = np.where((ethnicity_df_W.index == 'white'),'White',ethnicity_df_W.index)
ethnicity_df_W['ethnicity_text'] = np.where((ethnicity_df_W.index == 'non_white'),'Other than White', ethnicity_df_W.ethnicity_text)

ethnicity_df_W
# Out:
#            tweets_containing_slurs  tweets_flagged_perspective  \
# ethnicity
# non_white                13.055556                   12.555556
# white                    10.800000                    9.016667
#
#            hatebase_proportion  perspective_proportion    ethnicity_text
# ethnicity
# non_white             0.002728                0.001318  Other than White
# white                 0.002897                0.001721             White

# %%
normalising_factor = 100 / ethnicity_df_W['perspective_proportion'].max()

data = go.Bar(
    y = ethnicity_df_W.ethnicity_text,
    x = ethnicity_df_W.perspective_proportion * 100,
    text = ethnicity_df_W.perspective_proportion * 100,
    textposition = 'outside',
    texttemplate = '%{text:.5f}',
    orientation = 'h',
    width = [0.5]*2
)

layout = go.Layout(xaxis = dict(
                showticklabels = False,
                title = "Proportion of tweets flagged by Perspective"))

figure = go.Figure(data = data, layout = layout)
figure.update_traces(marker_color='green')

figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1466a020-7306-4d3a-bd5a-ab2ef345e7e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1466a020-7306-4d3a-bd5a-ab2ef345e7e5")) {                    Plotly.newPlot(                        "1466a020-7306-4d3a-bd5a-ab2ef345e7e5",                        [{"orientation":"h","text":[0.1318393210482855,0.17206762856217772],"textposition":"outside","texttemplate":"%{text:.5f}","width":[0.5,0.5],"x":[0.1318393210482855,0.17206762856217772],"y":["Other than White","White"],"type":"bar","marker":{"color":"green"}}],                        {"xaxis":{"showticklabels":false,"title":{"text":"Proportion of tweets flagged by Perspective"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"c ...

# %%
data = go.Bar(
    y = ethnicity_df_W.ethnicity_text,
    x = ethnicity_df_W.tweets_flagged_perspective,
    text = ethnicity_df_W.tweets_flagged_perspective,
    textposition = 'outside',
    texttemplate = '%{text:.1f}',
    orientation='h',
    width=[0.5]*2
)

layout = go.Layout(xaxis = dict(
                showticklabels = False,
                title = "Number of tweets flagged by Perspective (per player)"

    ))

figure = go.Figure(data = data, layout = layout)
figure.update_traces(marker_color='green')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ecb1a479-479e-4a37-a010-7b904a75fd4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ecb1a479-479e-4a37-a010-7b904a75fd4d")) {                    Plotly.newPlot(                        "ecb1a479-479e-4a37-a010-7b904a75fd4d",                        [{"orientation":"h","text":[12.555555555555555,9.016666666666667],"textposition":"outside","texttemplate":"%{text:.1f}","width":[0.5,0.5],"x":[12.555555555555555,9.016666666666667],"y":["Other than White","White"],"type":"bar","marker":{"color":"green"}}],                        {"xaxis":{"showticklabels":false,"title":{"text":"Number of tweets flagged by Perspective (per player)"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line ...

# %%
tmp_WL = reg_df[(reg_df['result'] == 'W') | (reg_df['result'] == 'L')]
print(tmp_WL['tweets_containing_slurs'].mean())
print(tmp_WL['tweets_flagged_perspective'].mean())
print(tmp_WL['hatebase_proportion'].mean() * 100)
print(tmp_WL['perspective_proportion'].mean()* 100) 

ethnicity_df_WL = tmp_WL.groupby('ethnicity').agg(({
    'tweets_containing_slurs': 'mean',
    'tweets_flagged_perspective': 'mean',
    'hatebase_proportion': 'mean',
    'perspective_proportion': 'mean'
    }
    ))
# Out:
# 28.966666666666665
# 25.641666666666666
# 0.2914473601572881
# 0.1748300935520736

# %%
ethnicity_df_WL
# Out:
#            tweets_containing_slurs  tweets_flagged_perspective  \
# ethnicity
# non_white                53.866667                   49.888889
# white                    14.026667                   11.093333
#
#            hatebase_proportion  perspective_proportion
# ethnicity
# non_white             0.003021                0.001716
# white                 0.002850                0.001768

# %%
ethnicity_df_WL['ethnicity_text'] = np.where((ethnicity_df_WL.index == 'white'),'White',ethnicity_df_WL.index)
ethnicity_df_WL['ethnicity_text'] = np.where((ethnicity_df_WL.index == 'non_white'),'Other than White', ethnicity_df_WL.ethnicity_text)

ethnicity_df_WL
# Out:
#            tweets_containing_slurs  tweets_flagged_perspective  \
# ethnicity
# non_white                53.866667                   49.888889
# white                    14.026667                   11.093333
#
#            hatebase_proportion  perspective_proportion    ethnicity_text
# ethnicity
# non_white             0.003021                0.001716  Other than White
# white                 0.002850                0.001768             White

# %%
data = go.Bar(
    y = ethnicity_df_WL.ethnicity_text,
    x = ethnicity_df_WL.tweets_flagged_perspective,
    text = ethnicity_df_WL.tweets_flagged_perspective,
    textposition = 'outside',
    texttemplate = '%{text:.1f}',
    orientation='h',
    width=[0.5]*2
)

layout = go.Layout(xaxis = dict(
                showticklabels = False,
                title = "Number of tweets flagged by Perspective (per player)"

    ))

figure = go.Figure(data = data, layout = layout)
figure.update_traces(marker_color='green')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="da8fe049-4c35-4986-bc5f-3f75164a7244" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da8fe049-4c35-4986-bc5f-3f75164a7244")) {                    Plotly.newPlot(                        "da8fe049-4c35-4986-bc5f-3f75164a7244",                        [{"orientation":"h","text":[49.888888888888886,11.093333333333334],"textposition":"outside","texttemplate":"%{text:.1f}","width":[0.5,0.5],"x":[49.888888888888886,11.093333333333334],"y":["Other than White","White"],"type":"bar","marker":{"color":"green"}}],                        {"xaxis":{"showticklabels":false,"title":{"text":"Number of tweets flagged by Perspective (per player)"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"li ...
